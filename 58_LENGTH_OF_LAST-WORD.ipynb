# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solution

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        s = s.split()
        return len(s[-1])
