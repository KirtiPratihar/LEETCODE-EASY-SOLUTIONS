# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
nums = [3,2,4]
l = []
target = 6
for i in range(len(nums)):
    for j in range(i):
        if nums[i]+nums[j] == target:
            l.append(j)
            l.append(i)
print(l)
# Out:
# [1, 2]
